# %%
import os, time, warnings, logging
warnings.filterwarnings("ignore")

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, WeightedRandomSampler
from torchvision import datasets, transforms, models
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from tqdm import tqdm

# =====================
# SETTINGS
# =====================
logging.basicConfig(level=logging.INFO, format='%(message)s')
logger = logging.getLogger()

DEVICE = torch.device("mps") if torch.backends.mps.is_available() else torch.device("cpu")
logger.info(f"⚡ Using {DEVICE}")

BATCH_SIZE = 16
EPOCHS = 50
IMG_SIZE = 224
PATIENCE = 5
MODE = "fine_tune"   # options: "feature_extraction" or "fine_tune"

TRAIN_DIR = r'/Users/muhammadmuhtasimshahriar/Downloads/archive/Training'
TEST_DIR  = r'/Users/muhammadmuhtasimshahriar/Downloads/archive/Testing'

# =====================
# DATA TRANSFORMS
# =====================
train_transform = transforms.Compose([
    transforms.RandomResizedCrop(IMG_SIZE, scale=(0.7, 1.0)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5),
    transforms.RandomRotation(20),
    transforms.ColorJitter(0.3,0.3,0.3,0.1),
    transforms.RandomAffine(0, shear=10, scale=(0.8,1.2)),
    transforms.RandomPerspective(distortion_scale=0.2, p=0.5),
    transforms.ToTensor(),
    transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])
])
test_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])
])

# =====================
# DATASETS
# =====================
train_dataset = datasets.ImageFolder(TRAIN_DIR, transform=train_transform)
test_dataset  = datasets.ImageFolder(TEST_DIR, transform=test_transform)

logger.info(f"📂 Train samples: {len(train_dataset)} | Classes: {train_dataset.classes}")
logger.info(f"📂 Test samples : {len(test_dataset)} | Classes: {test_dataset.classes}")

num_classes = len(train_dataset.classes)

# =====================
# BALANCED SAMPLER
# =====================
class_counts = np.bincount(train_dataset.targets)
class_weights = 1. / class_counts
samples_weight = [class_weights[t] for t in train_dataset.targets]
sampler = WeightedRandomSampler(samples_weight, num_samples=len(samples_weight), replacement=True)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, sampler=sampler, num_workers=0)
test_loader  = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=0)

# =====================
# MODEL: ResNet-101
# =====================
logger.info(f"🚀 Using ResNet-101 Pretrained Backbone ({MODE})")
model = models.resnet101(weights="IMAGENET1K_V1")

# Replace fc layer
in_features = model.fc.in_features
model.fc = nn.Sequential(
    nn.Linear(in_features, 512),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(512, num_classes)
)

# -------- MODE Handling --------
if MODE == "feature_extraction":
    for param in model.parameters():
        param.requires_grad = False
    for param in model.fc.parameters():
        param.requires_grad = True
    params_to_update = model.fc.parameters()
    LR = 1e-4
elif MODE == "fine_tune":
    for param in model.parameters():
        param.requires_grad = True
    params_to_update = model.parameters()
    LR = 1e-5

criterion = nn.CrossEntropyLoss(label_smoothing=0.05)
optimizer = optim.Adam(params_to_update, lr=LR)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode="max", patience=3, factor=0.3
)

model = model.to(DEVICE)

# =====================
# TRAINING LOOP
# =====================
best_f1, best_acc = 0, 0
best_f1_epoch, best_acc_epoch = 0, 0
patience_counter = 0

train_acc_list, test_acc_list, train_loss_list, test_loss_list, f1_list = [], [], [], [], []

start_time = time.time()
logger.info("\n🚀 Training ResNet-101...")

for epoch in range(EPOCHS):
    model.train()
    total_loss, correct, total = 0, 0, 0

    loop = tqdm(train_loader, desc=f"Epoch {epoch+1}/{EPOCHS} [Train]", leave=False)
    for imgs, labels in loop:
        imgs, labels = imgs.to(DEVICE), labels.to(DEVICE)
        optimizer.zero_grad()
        outputs = model(imgs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        preds = outputs.argmax(1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)
        loop.set_postfix(loss=loss.item())

    train_acc = correct / total
    train_loss = total_loss / len(train_loader)

    # ---- Evaluation ----
    model.eval()
    y_true, y_pred = [], []
    test_loss, correct, total = 0, 0, 0

    loop = tqdm(test_loader, desc=f"Epoch {epoch+1}/{EPOCHS} [Eval]", leave=False)
    with torch.no_grad():
        for imgs, labels in loop:
            imgs, labels = imgs.to(DEVICE), labels.to(DEVICE)
            outputs = model(imgs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            preds = outputs.argmax(1)
            y_true.extend(labels.cpu().numpy())
            y_pred.extend(preds.cpu().numpy())
            correct += (preds == labels).sum().item()
            total += labels.size(0)
            loop.set_postfix(loss=loss.item())

    test_acc = correct / total
    test_loss /= len(test_loader)
    test_f1 = f1_score(y_true, y_pred, average="macro")

    # Save history
    train_acc_list.append(train_acc)
    test_acc_list.append(test_acc)
    train_loss_list.append(train_loss)
    test_loss_list.append(test_loss)
    f1_list.append(test_f1)

    scheduler.step(test_f1)
    lr = optimizer.param_groups[0]['lr']

    logger.info(f"[Epoch {epoch+1:02d}] LR={lr:.2e} | "
                f"Train Acc={train_acc:.4f}, Test Acc={test_acc:.4f} | "
                f"Train Loss={train_loss:.4f}, Test Loss={test_loss:.4f} | "
                f"Test F1={test_f1:.4f}")

    # Track best F1
    if test_f1 > best_f1:
        best_f1 = test_f1
        best_f1_epoch = epoch + 1
        patience_counter = 0
        torch.save(model.state_dict(), f"best_resnet101_{MODE}.pth")
        logger.info(f"💾 New Best Model (F1) {best_f1:.4f} at Epoch {best_f1_epoch}")
    else:
        patience_counter += 1
        if patience_counter >= PATIENCE:
            logger.info("⏹ Early stopping triggered.")
            break

    # Track best Accuracy
    if test_acc > best_acc:
        best_acc = test_acc
        best_acc_epoch = epoch + 1

elapsed = (time.time()-start_time)/60
logger.info(f"\n⏱ Training finished in {elapsed:.1f} min.")

# =====================
# LOAD BEST MODEL
# =====================
model.load_state_dict(torch.load(f"best_resnet101_{MODE}.pth"))
model.eval()
logger.info("🔄 Loaded best saved ResNet-101 model for evaluation.")

# =====================
# FINAL EVALUATION
# =====================
y_true, y_pred = [], []
with torch.no_grad():
    for imgs, labels in test_loader:
        imgs, labels = imgs.to(DEVICE), labels.to(DEVICE)
        outputs = model(imgs)
        preds = outputs.argmax(1)
        y_true.extend(labels.cpu().numpy())
        y_pred.extend(preds.cpu().numpy())

final_acc = accuracy_score(y_true, y_pred)
final_prec = precision_score(y_true, y_pred, average="macro", zero_division=0)
final_rec = recall_score(y_true, y_pred, average="macro", zero_division=0)
final_f1 = f1_score(y_true, y_pred, average="macro", zero_division=0)

logger.info("\n📊 FINAL PERFORMANCE SUMMARY")
logger.info("=============================")
logger.info(f"✅ Accuracy         : {final_acc*100:.2f}%")
logger.info(f"🎯 Precision (Macro): {final_prec:.4f}")
logger.info(f"📌 Recall    (Macro): {final_rec:.4f}")
logger.info(f"📈 F1-Score  (Macro): {final_f1:.4f}")

logger.info("\n🏆 BEST EPOCH METRICS")
logger.info("=============================")
logger.info(f"📌 Highest Test Accuracy : {best_acc*100:.2f}% at Epoch {best_acc_epoch}")
logger.info(f"📌 Highest Test F1-Score : {best_f1:.4f} at Epoch {best_f1_epoch}")

# =====================
# CONFUSION MATRIX
# =====================
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 6))
sns.heatmap(cm, annot=True, fmt="d",
            xticklabels=test_dataset.classes,
            yticklabels=test_dataset.classes,
            cmap="Blues")
plt.title("Confusion Matrix")
plt.show()

# =====================
# TRAINING CURVES
# =====================
plt.figure()
plt.plot(train_loss_list, label="Train Loss")
plt.plot(test_loss_list, label="Test Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss Curves")
plt.legend()
plt.show()

plt.figure()
plt.plot(train_acc_list, label="Train Accuracy")
plt.plot(test_acc_list, label="Test Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Accuracy Curves")
plt.legend()
plt.show()

plt.figure()
plt.plot(f1_list, label="Test F1 Score (Macro)")
plt.xlabel("Epoch")
plt.ylabel("F1 Score")
plt.title("F1 Score Curve")
plt.legend()
plt.show()
# Out:
# ⚡ Using mps
# 📂 Train samples: 5710 | Classes: ['glioma', 'meningioma', 'notumor', 'pituitary']
# 📂 Test samples : 1309 | Classes: ['glioma', 'meningioma', 'notumor', 'pituitary']
# 🚀 Using ResNet-101 Pretrained Backbone (fine_tune)
#
# 🚀 Training ResNet-101...
# [Epoch 01] LR=1.00e-05 | Train Acc=0.7732, Test Acc=0.9114 | Train Loss=0.7632, Test Loss=0.4148 | Test F1=0.9079
# 💾 New Best Model (F1) 0.9079 at Epoch 1
# [Epoch 02] LR=1.00e-05 | Train Acc=0.9138, Test Acc=0.9381 | Train Loss=0.4222, Test Loss=0.3496 | Test F1=0.9358
# 💾 New Best Model (F1) 0.9358 at Epoch 2
# [Epoch 03] LR=1.00e-05 | Train Acc=0.9356, Test Acc=0.9519 | Train Loss=0.3657, Test Loss=0.3207 | Test F1=0.9506
# 💾 New Best Model (F1) 0.9506 at Epoch 3
# [Epoch 04] LR=1.00e-05 | Train Acc=0.9475, Test Acc=0.9610 | Train Loss=0.3395, Test Loss=0.3043 | Test F1=0.9599
# 💾 New Best Model (F1) 0.9599 at Epoch 4
# [Epoch 05] LR=1.00e-05 | Train Acc=0.9578, Test Acc=0.9702 | Train Loss=0.3107, Test Loss=0.2864 | Test F1=0.9691
# 💾 New Best Model (F1) 0.9691 at Epoch 5
# [Epoch 06] LR=1.00e-05 | Train Acc=0.9644, Test Acc=0.9824 | Train Loss=0.2983, Test Loss=0.2565 | Test F1=0.9815
# 💾 New Best Model (F1) 0.9815 at Epoch 6
# [Epoch 07] LR=1.00e-05 | Train Acc=0.9676, Test Acc=0.9801 | Train Loss=0.2949, Test Loss=0.2516 | Test F1=0.9793
# [Epoch 08] LR=1.00e-05 | Train Acc=0.9778, Test Acc=0.9817 | Train Loss=0.2716, Test Loss=0.2490 | Test F1=0.9805
# [Epoch 09] LR=1.00e-05 | Train Acc=0.9778, Test Acc=0.9801 | Train Loss=0.2702, Test Loss=0.2601 | Test F1=0.9788
# [Epoch 10] LR=1.00e-05 | Train Acc=0.9809, Test Acc=0.9847 | Train Loss=0.2632, Test Loss=0.2423 | Test F1=0.9838
# 💾 New Best Model (F1) 0.9838 at Epoch 10
# [Epoch 11] LR=1.00e-05 | Train Acc=0.9851, Test Acc=0.9832 | Train Loss=0.2512, Test Loss=0.2435 | Test F1=0.9826
# [Epoch 12] LR=1.00e-05 | Train Acc=0.9862, Test Acc=0.9901 | Train Loss=0.2479, Test Loss=0.2376 | Test F1=0.9894
# 💾 New Best Model (F1) 0.9894 at Epoch 12
# [Epoch 13] LR=1.00e-05 | Train Acc=0.9863, Test Acc=0.9924 | Train Loss=0.2489, Test Loss=0.2292 | Test F1=0.9918
# 💾 New Best Model (F1) 0.9918 at Epoch 13
# [Epoch 14] LR=1.00e-05 | Train Acc=0.9877, Test Acc=0.9878 | Train Loss=0.2418, Test Loss=0.2383 | Test F1=0.9871
# [Epoch 15] LR=1.00e-05 | Train Acc=0.9919, Test Acc=0.9901 | Train Loss=0.2352, Test Loss=0.2233 | Test F1=0.9895
# [Epoch 16] LR=1.00e-05 | Train Acc=0.9886, Test Acc=0.9916 | Train Loss=0.2400, Test Loss=0.2308 | Test F1=0.9910
# [Epoch 17] LR=1.00e-05 | Train Acc=0.9870, Test Acc=0.9947 | Train Loss=0.2418, Test Loss=0.2228 | Test F1=0.9942
# 💾 New Best Model (F1) 0.9942 at Epoch 17
# [Epoch 18] LR=1.00e-05 | Train Acc=0.9919, Test Acc=0.9924 | Train Loss=0.2315, Test Loss=0.2249 | Test F1=0.9920
# [Epoch 19] LR=1.00e-05 | Train Acc=0.9925, Test Acc=0.9947 | Train Loss=0.2291, Test Loss=0.2254 | Test F1=0.9943
# 💾 New Best Model (F1) 0.9943 at Epoch 19
# [Epoch 20] LR=1.00e-05 | Train Acc=0.9937, Test Acc=0.9962 | Train Loss=0.2255, Test Loss=0.2176 | Test F1=0.9959
# 💾 New Best Model (F1) 0.9959 at Epoch 20
# [Epoch 21] LR=1.00e-05 | Train Acc=0.9925, Test Acc=0.9916 | Train Loss=0.2292, Test Loss=0.2297 | Test F1=0.9913
# [Epoch 22] LR=1.00e-05 | Train Acc=0.9923, Test Acc=0.9916 | Train Loss=0.2283, Test Loss=0.2305 | Test F1=0.9909
# [Epoch 23] LR=1.00e-05 | Train Acc=0.9937, Test Acc=0.9931 | Train Loss=0.2269, Test Loss=0.2211 | Test F1=0.9926
# [Epoch 24] LR=3.00e-06 | Train Acc=0.9949, Test Acc=0.9916 | Train Loss=0.2226, Test Loss=0.2216 | Test F1=0.9910
# [Epoch 25] LR=3.00e-06 | Train Acc=0.9946, Test Acc=0.9931 | Train Loss=0.2213, Test Loss=0.2203 | Test F1=0.9928
# ⏹ Early stopping triggered.
#
# ⏱ Training finished in 180.2 min.
# 🔄 Loaded best saved ResNet-101 model for evaluation.
#
# 📊 FINAL PERFORMANCE SUMMARY
# =============================
# ✅ Accuracy         : 99.62%
# 🎯 Precision (Macro): 0.9959
# 📌 Recall    (Macro): 0.9958
# 📈 F1-Score  (Macro): 0.9959
#
# 🏆 BEST EPOCH METRICS
# =============================
# 📌 Highest Test Accuracy : 99.62% at Epoch 20
# 📌 Highest Test F1-Score : 0.9959 at Epoch 20
