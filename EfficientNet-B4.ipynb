# %%
import os, time, warnings, logging
warnings.filterwarnings("ignore")

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, WeightedRandomSampler
from torchvision import datasets, transforms, models
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# =====================
# SETTINGS
# =====================
logging.basicConfig(level=logging.INFO, format='%(message)s')
logger = logging.getLogger()

DEVICE = torch.device("mps" if torch.backends.mps.is_available() else "cpu")  # use Apple GPU
BATCH_SIZE = 16
EPOCHS = 30
IMG_SIZE = 224   # smaller for better speed
LR = 1e-5
PATIENCE = 5

TRAIN_DIR = r'/Users/muhammadmuhtasimshahriar/Downloads/archive/Training'
TEST_DIR  = r'/Users/muhammadmuhtasimshahriar/Downloads/archive/Testing'

# =====================
# DATA TRANSFORMS
# =====================
train_transform = transforms.Compose([
    transforms.RandomResizedCrop(IMG_SIZE, scale=(0.8, 1.0)),
    transforms.RandomRotation(15),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])
test_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# =====================
# DATASETS & CLASSES
# =====================
train_dataset = datasets.ImageFolder(TRAIN_DIR, transform=train_transform)
test_dataset  = datasets.ImageFolder(TEST_DIR, transform=test_transform)

logger.info(f"📂 Train samples: {len(train_dataset)} | Classes: {train_dataset.classes}")
logger.info(f"📂 Test samples : {len(test_dataset)} | Classes: {test_dataset.classes}")

num_classes = len(train_dataset.classes)

# =====================
# BALANCED SAMPLER
# =====================
class_counts = np.bincount(train_dataset.targets)
class_weights = 1. / class_counts
samples_weight = [class_weights[t] for t in train_dataset.targets]
sampler = WeightedRandomSampler(samples_weight, num_samples=len(samples_weight), replacement=True)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, sampler=sampler, num_workers=0)
test_loader  = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=0)

# =====================
# MODEL: EfficientNet-B4
# =====================
logger.info("🚀 Using EfficientNet-B4 Pretrained Backbone")
model = models.efficientnet_b4(weights="IMAGENET1K_V1")
in_features = model.classifier[1].in_features
model.classifier[1] = nn.Linear(in_features, num_classes)

for param in model.parameters():
    param.requires_grad = True

criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
optimizer = optim.Adam(model.parameters(), lr=LR)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode="max", patience=3, factor=0.3)

model = model.to(DEVICE)

# =====================
# TRAINING
# =====================
best_f1, patience_counter, best_epoch = 0, 0, 0
train_acc_list, test_acc_list = [], []
train_loss_list, test_loss_list, f1_list = [], [], []

start_time = time.time()
logger.info("\n🚀 Training EfficientNet-B4...")

for epoch in range(EPOCHS):
    model.train()
    total_loss, correct, total = 0, 0, 0

    for imgs, labels in train_loader:
        imgs, labels = imgs.to(DEVICE), labels.to(DEVICE)
        optimizer.zero_grad()
        outputs = model(imgs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        preds = outputs.argmax(1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    train_acc = correct / total
    train_loss = total_loss / len(train_loader)

    # ---- Eval ----
    model.eval()
    y_true, y_pred = [], []
    test_loss, correct, total = 0, 0, 0
    with torch.no_grad():
        for imgs, labels in test_loader:
            imgs, labels = imgs.to(DEVICE), labels.to(DEVICE)
            outputs = model(imgs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            preds = outputs.argmax(1)
            y_true.extend(labels.cpu().numpy())
            y_pred.extend(preds.cpu().numpy())
            correct += (preds == labels).sum().item()
            total += labels.size(0)

    test_acc = correct / total
    test_loss /= len(test_loader)
    test_f1 = f1_score(y_true, y_pred, average="macro")

    # Record
    train_acc_list.append(train_acc)
    test_acc_list.append(test_acc)
    train_loss_list.append(train_loss)
    test_loss_list.append(test_loss)
    f1_list.append(test_f1)

    scheduler.step(test_f1)
    lr = optimizer.param_groups[0]['lr']

    logger.info(f"[Epoch {epoch+1:02d}] LR={lr:.2e} | "
                f"Train Acc={train_acc:.4f}, Test Acc={test_acc:.4f} | "
                f"Train Loss={train_loss:.4f}, Test Loss={test_loss:.4f} | "
                f"Test F1={test_f1:.4f}")

    # Save best
    if test_f1 > best_f1:
        best_f1 = test_f1
        best_epoch = epoch+1
        patience_counter = 0
        torch.save(model.state_dict(), "best_efficientnet_b4.pth")
        logger.info(f"💾 New Best Model: F1={best_f1:.4f} at Epoch {best_epoch}")
    else:
        patience_counter += 1
        if patience_counter >= PATIENCE:
            logger.info("⏹ Early stopping.")
            break

elapsed = (time.time()-start_time)/60
logger.info(f"\n⏱ Training finished in {elapsed:.1f} min. Best F1={best_f1:.4f} at epoch {best_epoch}")

# =====================
# EVALUATION
# =====================
model.load_state_dict(torch.load("best_efficientnet_b4.pth"))
model.eval()
y_true, y_pred = [], []
with torch.no_grad():
    for imgs, labels in test_loader:
        imgs, labels = imgs.to(DEVICE), labels.to(DEVICE)
        outputs = model(imgs)
        preds = outputs.argmax(1)
        y_true.extend(labels.cpu().numpy())
        y_pred.extend(preds.cpu().numpy())

final_acc = accuracy_score(y_true, y_pred)
final_prec = precision_score(y_true, y_pred, average="macro", zero_division=0)
final_rec = recall_score(y_true, y_pred, average="macro", zero_division=0)
final_f1 = f1_score(y_true, y_pred, average="macro", zero_division=0)

logger.info("\n📊 FINAL PERFORMANCE SUMMARY")
logger.info("===================================")
logger.info(f"✅ Accuracy         : {final_acc*100:.2f}%")
logger.info(f"🎯 Precision (Macro): {final_prec:.4f}")
logger.info(f"📌 Recall    (Macro): {final_rec:.4f}")
logger.info(f"📈 F1-Score  (Macro): {final_f1:.4f}")

# =====================
# CONFUSION MATRIX
# =====================
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 6))
sns.heatmap(cm, annot=True, fmt="d",
            xticklabels=test_dataset.classes,
            yticklabels=test_dataset.classes,
            cmap="Blues")
plt.title("Confusion Matrix")
plt.show()

# =====================
# TRAINING CURVES
# =====================
plt.figure()
plt.plot(train_loss_list, label="Train Loss")
plt.plot(test_loss_list, label="Test Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss Curves")
plt.legend()
plt.show()

plt.figure()
plt.plot(train_acc_list, label="Train Accuracy")
plt.plot(test_acc_list, label="Test Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Accuracy Curves")
plt.legend()
plt.show()

plt.figure()
plt.plot(f1_list, label="Test F1 Score (Macro)")
plt.xlabel("Epoch")
plt.ylabel("F1 Score")
plt.title("F1 Score Curve")
plt.legend()
plt.show()
# Out:
# 📂 Train samples: 5710 | Classes: ['glioma', 'meningioma', 'notumor', 'pituitary']
# 📂 Test samples : 1309 | Classes: ['glioma', 'meningioma', 'notumor', 'pituitary']
# 🚀 Using EfficientNet-B4 Pretrained Backbone
#
# 🚀 Training EfficientNet-B4...
# [Epoch 01] LR=1.00e-05 | Train Acc=0.4347, Test Acc=0.6180 | Train Loss=1.3441, Test Loss=1.3424 | Test F1=0.5844
# 💾 New Best Model: F1=0.5844 at Epoch 1
# [Epoch 02] LR=1.00e-05 | Train Acc=0.6257, Test Acc=0.7082 | Train Loss=1.2185, Test Loss=1.1298 | Test F1=0.6643
# 💾 New Best Model: F1=0.6643 at Epoch 2
# [Epoch 03] LR=1.00e-05 | Train Acc=0.7124, Test Acc=0.7517 | Train Loss=1.0119, Test Loss=0.9105 | Test F1=0.7220
# 💾 New Best Model: F1=0.7220 at Epoch 3
# [Epoch 04] LR=1.00e-05 | Train Acc=0.7697, Test Acc=0.7846 | Train Loss=0.8415, Test Loss=0.8485 | Test F1=0.7731
# 💾 New Best Model: F1=0.7731 at Epoch 4
# [Epoch 05] LR=1.00e-05 | Train Acc=0.8044, Test Acc=0.7991 | Train Loss=0.7434, Test Loss=0.7923 | Test F1=0.7856
# 💾 New Best Model: F1=0.7856 at Epoch 5
# [Epoch 06] LR=1.00e-05 | Train Acc=0.8298, Test Acc=0.8029 | Train Loss=0.6977, Test Loss=0.7188 | Test F1=0.7945
# 💾 New Best Model: F1=0.7945 at Epoch 6
# [Epoch 07] LR=1.00e-05 | Train Acc=0.8450, Test Acc=0.8113 | Train Loss=0.6716, Test Loss=0.7129 | Test F1=0.8017
# 💾 New Best Model: F1=0.8017 at Epoch 7
# [Epoch 08] LR=1.00e-05 | Train Acc=0.8452, Test Acc=0.8228 | Train Loss=0.6553, Test Loss=0.8389 | Test F1=0.8163
# 💾 New Best Model: F1=0.8163 at Epoch 8
# [Epoch 09] LR=1.00e-05 | Train Acc=0.8574, Test Acc=0.8220 | Train Loss=0.6411, Test Loss=0.7347 | Test F1=0.8154
# [Epoch 10] LR=1.00e-05 | Train Acc=0.8665, Test Acc=0.8365 | Train Loss=0.6280, Test Loss=0.6890 | Test F1=0.8306
# 💾 New Best Model: F1=0.8306 at Epoch 10
# [Epoch 11] LR=1.00e-05 | Train Acc=0.8781, Test Acc=0.8335 | Train Loss=0.6121, Test Loss=0.6629 | Test F1=0.8289
# [Epoch 12] LR=1.00e-05 | Train Acc=0.8855, Test Acc=0.8594 | Train Loss=0.5979, Test Loss=0.6459 | Test F1=0.8533
# 💾 New Best Model: F1=0.8533 at Epoch 12
# [Epoch 13] LR=1.00e-05 | Train Acc=0.8818, Test Acc=0.8579 | Train Loss=0.5950, Test Loss=0.6597 | Test F1=0.8533
# 💾 New Best Model: F1=0.8533 at Epoch 13
# [Epoch 14] LR=1.00e-05 | Train Acc=0.8898, Test Acc=0.8655 | Train Loss=0.5810, Test Loss=0.6656 | Test F1=0.8606
# 💾 New Best Model: F1=0.8606 at Epoch 14
# [Epoch 15] LR=1.00e-05 | Train Acc=0.8975, Test Acc=0.8678 | Train Loss=0.5703, Test Loss=0.6665 | Test F1=0.8635
# 💾 New Best Model: F1=0.8635 at Epoch 15
# [Epoch 16] LR=1.00e-05 | Train Acc=0.9000, Test Acc=0.8877 | Train Loss=0.5653, Test Loss=0.5745 | Test F1=0.8840
# 💾 New Best Model: F1=0.8840 at Epoch 16
# [Epoch 17] LR=1.00e-05 | Train Acc=0.9054, Test Acc=0.8839 | Train Loss=0.5522, Test Loss=0.7008 | Test F1=0.8804
# [Epoch 18] LR=1.00e-05 | Train Acc=0.9056, Test Acc=0.8953 | Train Loss=0.5488, Test Loss=0.5834 | Test F1=0.8920
# 💾 New Best Model: F1=0.8920 at Epoch 18
# [Epoch 19] LR=1.00e-05 | Train Acc=0.9123, Test Acc=0.8999 | Train Loss=0.5407, Test Loss=0.5535 | Test F1=0.8978
# 💾 New Best Model: F1=0.8978 at Epoch 19
# [Epoch 20] LR=1.00e-05 | Train Acc=0.9142, Test Acc=0.9121 | Train Loss=0.5326, Test Loss=0.5795 | Test F1=0.9101
# 💾 New Best Model: F1=0.9101 at Epoch 20
# [Epoch 21] LR=1.00e-05 | Train Acc=0.9191, Test Acc=0.9076 | Train Loss=0.5229, Test Loss=0.5398 | Test F1=0.9054
# [Epoch 22] LR=1.00e-05 | Train Acc=0.9205, Test Acc=0.9213 | Train Loss=0.5223, Test Loss=0.5255 | Test F1=0.9191
# 💾 New Best Model: F1=0.9191 at Epoch 22
# [Epoch 23] LR=1.00e-05 | Train Acc=0.9278, Test Acc=0.9175 | Train Loss=0.5102, Test Loss=0.5385 | Test F1=0.9160
# [Epoch 24] LR=1.00e-05 | Train Acc=0.9250, Test Acc=0.9244 | Train Loss=0.5079, Test Loss=0.5408 | Test F1=0.9221
# 💾 New Best Model: F1=0.9221 at Epoch 24
# [Epoch 25] LR=1.00e-05 | Train Acc=0.9313, Test Acc=0.9190 | Train Loss=0.5002, Test Loss=0.5915 | Test F1=0.9176
# [Epoch 26] LR=1.00e-05 | Train Acc=0.9291, Test Acc=0.9297 | Train Loss=0.5043, Test Loss=0.5056 | Test F1=0.9278
# 💾 New Best Model: F1=0.9278 at Epoch 26
# [Epoch 27] LR=1.00e-05 | Train Acc=0.9384, Test Acc=0.9343 | Train Loss=0.4918, Test Loss=0.5328 | Test F1=0.9330
# 💾 New Best Model: F1=0.9330 at Epoch 27
# [Epoch 28] LR=1.00e-05 | Train Acc=0.9382, Test Acc=0.9320 | Train Loss=0.4908, Test Loss=0.5316 | Test F1=0.9310
# [Epoch 29] LR=1.00e-05 | Train Acc=0.9413, Test Acc=0.9328 | Train Loss=0.4874, Test Loss=0.5699 | Test F1=0.9314
# [Epoch 30] LR=1.00e-05 | Train Acc=0.9410, Test Acc=0.9473 | Train Loss=0.4831, Test Loss=0.5094 | Test F1=0.9461
# 💾 New Best Model: F1=0.9461 at Epoch 30
#
# ⏱ Training finished in 208.5 min. Best F1=0.9461 at epoch 30
#
# 📊 FINAL PERFORMANCE SUMMARY
# ===================================
# ✅ Accuracy         : 94.73%
# 🎯 Precision (Macro): 0.9477
# 📌 Recall    (Macro): 0.9450
# 📈 F1-Score  (Macro): 0.9461
